# %% [markdown]
# # Inspect Data

# %%
import pandas as pd
import numpy as np

data = pd.read_excel('/content/AR Aging Domestic 06302025 (Sharepoint) -- Edited .xlsx')
#data.info()
total_rows = data.shape[0]

# %% [markdown]
# #Identify Overpayment Past 30 Days

# %%
import pandas as pd
import numpy as np

data = pd.read_excel('/content/AR Aging Domestic 06302025 (Sharepoint) -- Edited .xlsx') # <0 categorizes an 'overpayment'
overpayment_past_30 = data[data['Days31to60'] < 0].groupby(['Site Name', 'Customer Name'])['Days31to60'].sum().reset_index().sort_values(by='Days31to60', ascending=True)
print(overpayment_past_30)
# Out:
#                                Site Name                   Customer Name  \
# 1                     832 Communications              DEL WEBB SUNBRIDGE
# 4                       Packing District         HIGH POINT CLIMBING LLC
# 0                     832 Communications      ASHTON WOODS HOMES ORLANDO
# 5  Renaissance World Golf Village Resort  NEW CINGULAR WIRELESS PCS, LLC
# 3             Minnesota State Fair DAS 1            T-MOBILE CENTRAL LLC
# 2             Minnesota State Fair DAS 1              SPRINT SPECTRUM LP
#
#    Days31to60
# 1     -750.00
# 4     -476.15
# 0     -426.00
# 5      -21.14
# 3       -0.01
# 2       -0.01

# %%
print(data.columns)
# Out:
# Index(['Report Date', 'SBACompany', 'Site Name', 'Parents', 'Customer\nNumber',
#        'Customer Name', 'Doc Year Month', 'Document\nDate', 'GLPOSTDT',
#        'Document\nNumber', 'Doc Type Desc', 'Collections Note',
#        'Document Status', 'FUNLCURR', 'Tax Amnt', 'Total',
#        'Inv Bal Subj To Aging', 'Unapplied', 'Current Due', 'Days31to60',
#        'Days61to90', 'Over90', 'Days91to120', 'Days121to180', 'Days181to360',
#        'Over360', 'Orig Currency', 'Orig Total', 'Orig Balance',
#        'Payment Frequency', 'Transaction Name', 'Balance Group', 'Big4',
#        'Cust Clas', 'Company Type', 'Municipality', 'State', 'Project Group',
#        'SOPNote'],
#       dtype='object')

# %% [markdown]
# #Identify Overpayment Past 60 Days

# %%
import pandas as pd #Keep in mind if the Site Name and Customer Name are the same the totals displayed will displayed the sum
import numpy as np

data = pd.read_excel('/content/AR Aging Domestic 06302025 (Sharepoint) -- Edited .xlsx')
overpayment_past_60 = data[data['Days61to90'] < 0].groupby(['Site Name', 'Customer Name'])['Days61to90'].sum().reset_index().sort_values(by='Days61to90', ascending=True)
print(overpayment_past_60)
# Out:
#                        Site Name                         Customer Name  \
# 1             832 Communications                    DEL WEBB SUNBRIDGE
# 3             832 Communications                     TOLL SOUTHEAST LP
# 0             832 Communications            ASHTON WOODS HOMES ORLANDO
# 2             832 Communications                      PULTE GROUP, INC
# 4             832 Communications                    WEEKLEY HOMES, LLC
# 11    Minnesota State Fair DAS 1                    SPRINT SPECTRUM LP
# 6   Embassy Suites Dallas Frisco        NEW CINGULAR WIRELESS PCS, LLC
# 5             832 Communications  WESLYN PARK MASTER ASSOCIATION, INC.
# 9       Marriott Phoenix Airport                    CELLCO PARTNERSHIP
# 8           Glenwood Canyon oDAS        NEW CINGULAR WIRELESS PCS, LLC
# 10    Minnesota State Fair DAS 1        NEW CINGULAR WIRELESS PCS, LLC
# 13         TEXOMA MEDICAL CENTER        NEW CINGULAR WIRELESS PCS, LLC
# ...

# %% [markdown]
# #Identify Overpayment Past 90 Days

# %%
import pandas as pd
import numpy as np

data = pd.read_excel('/content/AR Aging Domestic 06302025 (Sharepoint) -- Edited .xlsx')
overpayment_past_90 = data[data['Over90'] < 0].groupby(['Site Name', 'Customer Name'])['Over90'].sum().reset_index().sort_values(by='Over90', ascending=True)
print(overpayment_past_90)
# Out:
#                                     Site Name  \
# 20      Renaissance World Golf Village Resort
# 18                   Palomar Imperial Village
# 19                      Palomar Serenity Lane
# 7                        Glenwood Canyon oDAS
# 17                        Palomar Harbour Cay
# 1                                    99 Ocean
# 21                            Summerdale Park
# 15                        Mizner Country Club
# 11                   Marriott Phoenix Airport
# 12                 Minnesota State Fair DAS 1
# 3                Embassy Suites Dallas Frisco
# 10              Marriot Phoenix at the Buttes
# 6                        Glenwood Canyon oDAS
# 0                          832 Communications
# 16                           Packing District
# 4                  Embassy Suites NW Arkansas
# 22                      TEXOMA MEDICAL CENTER
# 23                   Wellington (UHS) In-Bldg
# 8           Jefferson Regional Medical Center
# ...

# %% [markdown]
# #Identify Invoices Due Past 30 Days:

# %%
import pandas as pd
import numpy as np

data = pd.read_excel('/content/AR Aging Domestic 06302025 (Sharepoint) -- Edited .xlsx') # > 0 symbolizes an amount due to the company
invoices_past_30 = data[data['Days31to60'] > 0].groupby(['Site Name', 'Customer Name'])['Days31to60'].sum().reset_index().sort_values(by='Days31to60', ascending=True)
print(invoices_past_30)
# Out:
#                                Site Name  \
# 7  Renaissance World Golf Village Resort
# 0                     832 Communications
# 4                            First Light
# 6                          Laurel Pointe
# 1              CENTENNIAL HILLS HOSPITAL
# 2                DESERT SPRINGS HOSPITAL
# 5                     HENDERSON HOSPITAL
# 3                               Del Webb
#
#                                        Customer Name  Days31to60
# 7                     NEW CINGULAR WIRELESS PCS, LLC       22.97
# 0                                  TOLL SOUTHEAST LP      300.00
# 4                 VIRGINIA STREET JOINT VENTURE, LLC     1615.00
# 6  LAUREL POINTE COMMUNITY HOMEOWNERS ASSOCIATION...     8100.00
# 1                     NEW CINGULAR WIRELESS PCS, LLC    12000.00
# 2                     NEW CINGULAR WIRELESS PCS, LLC    12000.00
# 5                     NEW CINGULAR WIRELESS PCS, LLC    12000.00
# 3    DEL WEBB SUNBRIDGE HOMEOWNERS ASSOCIATION, INC.    50913.00

# %% [markdown]
# # Identify Invoices Due Past 60 Days:

# %%
import pandas as pd
import numpy as np
data = pd.read_excel('/content/AR Aging Domestic 06302025 (Sharepoint) -- Edited .xlsx')
invoices_past_60 = data[data['Days61to90'] > 0].groupby(['Site Name', 'Customer Name'])['Days61to90'].sum().reset_index().sort_values(by='Days61to90', ascending=False)
print(invoices_past_60)
# Out:
#                              Site Name  \
# 17            St. Augustine University
# 15                             Pier 66
# 14                      Parcel B Hotel
# 20                      Town Hollywood
# 0                   832 Communications
# 19                  The Tower Building
# 7                          First Light
# 12            NORTHWEST TEXAS HOSPITAL
# 9                   HENDERSON HOSPITAL
# 5            CENTENNIAL HILLS HOSPITAL
# 2                   832 Communications
# 6              DESERT SPRINGS HOSPITAL
# 13                  Omni Oklahoma City
# 16                RIVER CREST HOSPITAL
# 8                   GLEN OAKS HOSPITAL
# 1                   832 Communications
# 4                        Acadiana Mall
# 18  State of Michigan Capitol Campus 1
# 3                   832 Communications
# 11            Macy's Herald Sq In-Bldg
# 10   Jefferson Regional Medical Center
#
#                                         Customer Name  Days61to90
# ...

# %% [markdown]
# # Identify Invoices Due Past 90 Days:

# %%
import pandas as pd
import numpy as np

data = pd.read_excel('/content/AR Aging Domestic 06302025 (Sharepoint) -- Edited .xlsx')
invoices_past_90 = data[data['Over90'] > 0].groupby(['Site Name', 'Customer Name'])['Over90'].sum().reset_index().sort_values(by='Over90', ascending=False)
print(invoices_past_90)
# Out:
#                                     Site Name  \
# 44                   St. Augustine University
# 23                   Macy's Herald Sq In-Bldg
# 37                   Palomar Imperial Village
# 1                          832 Communications
# 8                   CENTENNIAL HILLS HOSPITAL
# 14                       GWU Hospital In-Bldg
# 19                         HENDERSON HOSPITAL
# 45         State of Michigan Capitol Campus 1
# 9                     DESERT SPRINGS HOSPITAL
# 24                   Macy's Herald Sq In-Bldg
# 16                       Glenwood Canyon oDAS
# 17                       Glenwood Canyon oDAS
# 51                   Wellington (UHS) In-Bldg
# 5                               Acadiana Mall
# 7                               Belle Isle MI
# 38                    Palomar Sunpointe Place
# 11               Embassy Suites Dallas Frisco
# 15                       Glenwood Canyon oDAS
# 42                       RIVER CREST HOSPITAL
# ...

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Total Overpayments

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel('/content/AR Aging Domestic 06302025 (Sharepoint) -- Edited .xlsx')
total_overpayment = data[data['Total']<0]['Total'].sum()
total_overpayment_accounts = data[data['Total']<0]['Total'].count()
print('$' + str(round(total_overpayment, 2)) + ' spanning across ' + str(total_overpayment_accounts) + ' accounts.')
# Out:
# $-1347169.49 spanning across 268 accounts.

# %% [markdown]
# ## Total Invoices Due

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel('/content/AR Aging Domestic 06302025 (Sharepoint) -- Edited .xlsx')
total_invoices_due = data[data['Total']>0]['Total'].sum()
total_invoices_due_accounts = data[data['Total']>0]['Total'].count()
print('$' + str(round(total_invoices_due, 2)) + ' spanning across ' + str(total_invoices_due_accounts) + ' accounts.')
# Out:
# $4480081.27 spanning across 661 accounts.

# %% [markdown]
# ## Overpayment Impact

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel('/content/AR Aging Domestic 06302025 (Sharepoint) -- Edited .xlsx')
percent_overpayment = round(total_overpayment_accounts / (total_overpayment_accounts + total_invoices_due_accounts) * 100, 2)
print('Overpayment accounts represent ' + str(percent_overpayment) + '% of all accounts listed on this report' +"'s" +' cashflows.')
# Out:
# Overpayment accounts represent 28.85% of all accounts listed on this report's cashflows.

# %% [markdown]
# ## Invoice Impact

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel('/content/AR Aging Domestic 06302025 (Sharepoint) -- Edited .xlsx')
percent_invoices_due = round(total_invoices_due_accounts / (total_overpayment_accounts + total_invoices_due_accounts) * 100, 2)
print('Invoices due represent ' + str(percent_invoices_due) + '% of all accounts listed on this report' +"'s" +' cashflows.')
# Out:
# Invoices due represent 71.15% of all accounts listed on this report's cashflows.

# %% [markdown]
# ## Cashflow Graph

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel('/content/AR Aging Domestic 06302025 (Sharepoint) -- Edited .xlsx')
cashflows = sns.barplot(x = [total_overpayment, total_invoices_due], )

# %%
# Assuming total_overpayment_accounts and total_invoices_due_accounts are already calculated
counts = [total_overpayment_accounts, total_invoices_due_accounts]
labels = ['Overpayment Accounts', 'Invoice Due Accounts']

plt.figure(figsize=(6, 4))
ax = sns.barplot(x=labels, y=counts)
plt.ylabel('Number of Accounts')
plt.title('Number of Overpayment and Invoice Due Accounts')

# Add callouts on each bar
for i, count in enumerate(counts):
    ax.text(i, count + 5, str(count), ha='center') # Added 5 for slight offset above the bar

plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel('/content/AR Aging Domestic 06302025 (Sharepoint) -- Edited .xlsx')
# Select only numeric columns for correlation calculation
numeric_data = data.select_dtypes(include=np.number)
plt.figure(figsize=(14, 10)) # Increased figure size
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # Consolidated Script for PowerBI

# %%
# Approach 1: Save combined_cashflow DataFrame to CSV
output_path_cashflow = '/content/drive/MyDrive/Power_BI_Data/customer_cashflow_summary.csv'
combined_cashflow.to_csv(output_path_cashflow, index=False)
print(f"Customer cashflow summary saved to {output_path_cashflow}")
# Out:
# Customer cashflow summary saved to /content/drive/MyDrive/Power_BI_Data/customer_cashflow_summary.csv

# %%
# Approach 2: Combine and save aging data to CSV

# Add a 'Aging_Period' and 'Type' column to each aging DataFrame
invoices_past_30['Aging_Period'] = '31-60 Days'
invoices_past_30['Type'] = 'Invoice Due'
overpayment_past_30['Aging_Period'] = '31-60 Days'
overpayment_past_30['Type'] = 'Overpayment'

invoices_past_60['Aging_Period'] = '61-90 Days'
invoices_past_60['Type'] = 'Invoice Due'
overpayment_past_60['Aging_Period'] = '61-90 Days'
overpayment_past_60['Type'] = 'Overpayment'

invoices_past_90['Aging_Period'] = 'Over 90 Days'
invoices_past_90['Type'] = 'Invoice Due'
overpayment_past_90['Aging_Period'] = 'Over 90 Days'
overpayment_past_90['Type'] = 'Overpayment'


# Rename the value columns for consistency before concatenating
invoices_past_30 = invoices_past_30.rename(columns={'Days31to60': 'Amount'})
overpayment_past_30 = overpayment_past_30.rename(columns={'Days31to60': 'Amount'})
invoices_past_60 = invoices_past_60.rename(columns={'Days61to90': 'Amount'})
overpayment_past_60 = overpayment_past_60.rename(columns={'Days61to90': 'Amount'})
invoices_past_90 = invoices_past_90.rename(columns={'Over90': 'Amount'})
overpayment_past_90 = overpayment_past_90.rename(columns={'Over90': 'Amount'})


# Concatenate all aging DataFrames
all_aging_data = pd.concat([
    invoices_past_30, overpayment_past_30,
    invoices_past_60, overpayment_past_60,
    invoices_past_90, overpayment_past_90
], ignore_index=True)

# Define the output path for aging data
output_path_aging = '/content/drive/MyDrive/Power_BI_Data/aging_details.csv'

# Save the combined aging DataFrame to a CSV file
all_aging_data.to_csv(output_path_aging, index=False)

print(f"Aging details saved to {output_path_aging}")
# Out:
# Aging details saved to /content/drive/MyDrive/Power_BI_Data/aging_details.csv

# %%
# Recreate combined_cashflow with modified structure

# Separate data into overpayments and invoices due
overpayments_by_customer = data[data['Total'] < 0].groupby('Customer Name')['Total'].sum().reset_index()
overpayments_by_customer['Type'] = 'Overpayment'

invoices_by_customer = data[data['Total'] > 0].groupby('Customer Name')['Total'].sum().reset_index()
invoices_by_customer['Type'] = 'Invoice Due'

# Combine the dataframes
combined_cashflow = pd.concat([overpayments_by_customer, invoices_by_customer])

# Rename 'Total' to 'Amount' and add 'Site Name' and 'Aging_Period' columns
combined_cashflow = combined_cashflow.rename(columns={'Total': 'Amount'})
combined_cashflow['Site Name'] = 'All Sites' # Placeholder for customer totals
combined_cashflow['Aging_Period'] = 'Overall' # Placeholder for customer totals

# Select and reorder columns to match the target structure
combined_cashflow = combined_cashflow[['Site Name', 'Customer Name', 'Amount', 'Aging_Period', 'Type']]

# Display the head of the modified combined_cashflow
print("Modified combined_cashflow DataFrame:")
display(combined_cashflow.head())
# Out:
# Modified combined_cashflow DataFrame:
#    Site Name                Customer Name    Amount Aging_Period         Type
# 0  All Sites        12001 BELCHER RD, LLC -12789.00      Overall  Overpayment
# 1  All Sites  2065 N HIGHLAND AVENUE, LLC -31020.27      Overall  Overpayment
# 2  All Sites       9790 HAMLIN BLVD., LLC -23373.00      Overall  Overpayment
# 3  All Sites         99 OCEAN AVENUE, LLC  -4720.00      Overall  Overpayment
# 4  All Sites   ASHTON WOODS HOMES ORLANDO  -2871.00      Overall  Overpayment

# %%
# Recreate all_aging_data with modified structure (already close, just ensure column order)

# Add a 'Aging_Period' and 'Type' column to each aging DataFrame (already done in previous code, but repeating for clarity)
invoices_past_30['Aging_Period'] = '31-60 Days'
invoices_past_30['Type'] = 'Invoice Due'
overpayment_past_30['Aging_Period'] = '31-60 Days'
overpayment_past_30['Type'] = 'Overpayment'

invoices_past_60['Aging_Period'] = '61-90 Days'
invoices_past_60['Type'] = 'Invoice Due' # Corrected typo here
overpayment_past_60['Aging_Period'] = '61-90 Days'
overpayment_past_60['Type'] = 'Overpayment'

invoices_past_90['Aging_Period'] = 'Over 90 Days'
invoices_past_90['Type'] = 'Invoice Due'
overpayment_past_90['Aging_Period'] = 'Over 90 Days'
overpayment_past_90['Type'] = 'Overpayment'

# Rename the value columns for consistency (already done, but repeating for clarity)
invoices_past_30 = invoices_past_30.rename(columns={'Days31to60': 'Amount'})
overpayment_past_30 = overpayment_past_30.rename(columns={'Days31to60': 'Amount'})
invoices_past_60 = invoices_past_60.rename(columns={'Days61to90': 'Amount'})
overpayment_past_60 = overpayment_past_60.rename(columns={'Days61to90': 'Amount'})
invoices_past_90 = invoices_past_90.rename(columns={'Over90': 'Amount'})
overpayment_past_90 = overpayment_past_90.rename(columns={'Over90': 'Amount'})

# Concatenate all aging DataFrames
all_aging_data = pd.concat([
    invoices_past_30, overpayment_past_30,
    invoices_past_60, overpayment_past_60,
    invoices_past_90, overpayment_past_90
], ignore_index=True)

# Select and reorder columns to match the target structure
all_aging_data = all_aging_data[['Site Name', 'Customer Name', 'Amount', 'Aging_Period', 'Type']]


# Display the head of the modified all_aging_data
print("\nModified all_aging_data DataFrame:")
display(all_aging_data.head())
# Out:
# Modified all_aging_data DataFrame:
#                                Site Name  \
# 0  Renaissance World Golf Village Resort
# 1                     832 Communications
# 2                            First Light
# 3                          Laurel Pointe
# 4              CENTENNIAL HILLS HOSPITAL
#
#                                        Customer Name    Amount Aging_Period  \
# 0                     NEW CINGULAR WIRELESS PCS, LLC     22.97   31-60 Days
# 1                                  TOLL SOUTHEAST LP    300.00   31-60 Days
# 2                 VIRGINIA STREET JOINT VENTURE, LLC   1615.00   31-60 Days
# 3  LAUREL POINTE COMMUNITY HOMEOWNERS ASSOCIATION...   8100.00   31-60 Days
# 4                     NEW CINGULAR WIRELESS PCS, LLC  12000.00   31-60 Days
#
#           Type
# 0  Invoice Due
# 1  Invoice Due
# 2  Invoice Due
# 3  Invoice Due
# 4  Invoice Due
